# %%
import pandas as pd

arq = pd.read_excel('/content/drive/MyDrive/Faculdade /Projeto CAP/Dados/Embrapa extraido /Dados de produção.xlsx')

arq.head()

arq.dtypes
# Out:
# PONTO              object
# RESUMO kg / há    float64
# Arrobas @/ha      float64
# dtype: object

# %%
arq['RESUMO kg / há'] = arq['RESUMO kg / há'].str.replace(',','.')
arq['Arrobas @/ha '] = arq['Arrobas @/ha '].str.replace(',','.')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-6b599e9710ee> in <module>
# ----> 1 arq['RESUMO kg / há'] = arq['RESUMO kg / há'].str.replace(',','.')
#       2 arq['Arrobas @/ha '] = arq['Arrobas @/ha '].str.replace(',','.')
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
# ...
