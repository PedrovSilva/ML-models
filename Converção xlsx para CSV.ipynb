# %%
import pandas as pd

arq = pd.read_excel('/content/drive/MyDrive/Faculdade /Projeto CAP/Dados/Embrapa extraido /SOLO_ANÁLISES DUAS TOMADAS empresa_brasileira_de_pesquisa_agropecuaria____embrapa_sao_carlos (2).xls')

arq.head()
# Out:
#            OS  Amostra  Talhão Ponto de coleta ARGILA! H2O(pH)   SMP  \
# 0  S_12981/2022.Sl.1.1     NaN   AMOSTRA 1 - A   27,00     6,0  6,40
# 1  S_12981/2022.Sl.2.1     NaN   AMOSTRA 2 - A   27,00     6,2  6,70
# 2  S_12981/2022.Sl.3.1     NaN   AMOSTRA 3 - A   24,00     6,8  7,00
# 3  S_12981/2022.Sl.4.1     NaN   AMOSTRA 4 - A   24,00     6,5  6,70
# 4  S_12981/2022.Sl.5.1     NaN   AMOSTRA 5 - A   25,00     6,7  6,90
#
#   P(mg/dm3) K(mg/dm3) K(cmolc/dm3) M.O.(%)  ...   K %   Mg %   Ca % Prote  \
# 0     14,06    116,18         0,30    2,85  ...  3,69  11,17  50,89   NaN
# 1     12,10     43,28         0,11    3,00  ...  1,36  14,72  59,93   NaN
# 2     18,39     59,76         0,15    3,62  ...  1,50  18,49  66,43   NaN
# 3     15,14     55,55         0,14    3,26  ...  1,55  15,38  61,77   NaN
# 4      9,52     35,65         0,09    2,87  ...  1,16  13,00  66,08   NaN
#
#   Nitrog Fe amorfo Sodio(mg/dm3) Condutividade Soma de Bases P Resina
# ...

# %%
arq.dtypes
# Out:
# OS  Amostra              object
# Talhão                  float64
# Ponto de coleta          object
# ARGILA!                  object
# H2O(pH)                  object
# SMP                      object
# P(mg/dm3)                object
# K(mg/dm3)                object
# K(cmolc/dm3)             object
# M.O.(%)                  object
# Al(cmolc/dm3)            object
# Ca(cmolc/dm3)            object
# Mg(cmolc/dm3)            object
# Al+H(cmolc/dm3)          object
# CTC(cmolc/dm3)           object
# %SAT.CTC(Bases)          object
# %SAT.CTC(Al)             object
# Rel.Ca/Mg                object
# Rel.Ca/K                 object
# Rel.Mg/k                 object
# S(mg/dm3)               float64
# Zn(mg/dm3)               object
# Cu(mg/dm3)               object
# B(mg/dm3)                object
# Mn(mg/dm3)               object
# Silte(%)                float64
# Carbono                  object
# Ferro                    object
# Areia(%)                float64
# ...

# %%
#arq['ARGILA!'] = arq['ARGILA!'].str.replace(',','.')
arq['H2O(pH)'] = arq['H2O(pH)'].str.replace(',','.')
arq['SMP'] = arq['SMP'].str.replace(',','.')
arq['P(mg/dm3)'] = arq['P(mg/dm3)'].str.replace(',','.')
arq['K(mg/dm3)'] = arq['K(mg/dm3)'].str.replace(',','.')
arq['K(cmolc/dm3)'] = arq['K(cmolc/dm3)'].str.replace(',','.')
arq['M.O.(%)'] = arq['M.O.(%)'].str.replace(',','.')
arq['Al(cmolc/dm3)'] = arq['Al(cmolc/dm3)'].str.replace(',','.')
arq['Ca(cmolc/dm3)'] = arq['Ca(cmolc/dm3)'].str.replace(',','.')
arq['Mg(cmolc/dm3)'] = arq['Mg(cmolc/dm3)'].str.replace(',','.')
arq['Al+H(cmolc/dm3)'] = arq['Al+H(cmolc/dm3)'].str.replace(',','.')
arq['CTC(cmolc/dm3)'] = arq['CTC(cmolc/dm3)'].str.replace(',','.')
arq['%SAT.CTC(Bases)'] = arq['%SAT.CTC(Bases)'].str.replace(',','.')
arq['%SAT.CTC(Al)'] = arq['%SAT.CTC(Al)'].str.replace(',','.')
arq['Rel.Ca/Mg'] = arq['Rel.Ca/Mg'].str.replace(',','.')
arq['Rel.Ca/K'] = arq['Rel.Ca/K'].str.replace(',','.')
arq['Rel.Mg/k'] = arq['Rel.Mg/k'].str.replace(',','.')
arq['Zn(mg/dm3)'] = arq['Zn(mg/dm3)'].str.replace(',','.')
arq['Cu(mg/dm3)'] = arq['Cu(mg/dm3)'].str.replace(',','.')
arq['B(mg/dm3)'] = arq['B(mg/dm3)'].str.replace(',','.')
arq['Mn(mg/dm3)'] = arq['Mn(mg/dm3)'].str.replace(',','.')
arq['Carbono'] = arq['Carbono'].str.replace(',','.')
arq['Ferro'] = arq['Ferro'].str.replace(',','.')
arq['K na CTC'] = arq['K na CTC'].str.replace(',','.')
arq['Ca na CTC'] = arq['Ca na CTC'].str.replace(',','.')
arq['Mg na CTC'] = arq['Mg na CTC'].str.replace(',','.')
arq['CTC pH7'] = arq['CTC pH7'].str.replace(',','.')
arq['K %'] = arq['K %'].str.replace(',','.')
arq['Mg %'] = arq['Mg %'].str.replace(',','.')
arq['Ca %'] = arq['Ca %'].str.replace(',','.')
arq['Sodio(mg/dm3)'] = arq['Sodio(mg/dm3)'].str.replace(',','.')
arq['Soma de Bases'] = arq['Soma de Bases'].str.replace(',','.')
arq['P Resina'] = arq['P Resina'].str.replace(',','.')

# %%
#arq['ARGILA!'] = arq['ARGILA!'].str.replace(',','.')
arq['H2O(pH)'] = arq['H2O(pH)'].astype(float)
arq['SMP'] = arq['SMP'].astype(float)
arq['P(mg/dm3)'] = arq['P(mg/dm3)'].astype(float)
arq['K(mg/dm3)'] = arq['K(mg/dm3)'].astype(float)
arq['K(cmolc/dm3)'] = arq['K(cmolc/dm3)'].astype(float)
arq['M.O.(%)'] = arq['M.O.(%)'].astype(float)
arq['Al(cmolc/dm3)'] = arq['Al(cmolc/dm3)'].astype(float)
arq['Ca(cmolc/dm3)'] = arq['Ca(cmolc/dm3)'].astype(float)
arq['Mg(cmolc/dm3)'] = arq['Mg(cmolc/dm3)'].astype(float)
arq['Al+H(cmolc/dm3)'] = arq['Al+H(cmolc/dm3)'].astype(float)
arq['CTC(cmolc/dm3)'] = arq['CTC(cmolc/dm3)'].astype(float)
arq['%SAT.CTC(Bases)'] = arq['%SAT.CTC(Bases)'].astype(float)
arq['%SAT.CTC(Al)'] = arq['%SAT.CTC(Al)'].astype(float)
arq['Rel.Ca/Mg'] = arq['Rel.Ca/Mg'].astype(float)
arq['Rel.Ca/K'] = arq['Rel.Ca/K'].astype(float)
arq['Rel.Mg/k'] = arq['Rel.Mg/k'].astype(float)
arq['Zn(mg/dm3)'] = arq['Zn(mg/dm3)'].astype(float)
arq['Cu(mg/dm3)'] = arq['Cu(mg/dm3)'].astype(float)
arq['B(mg/dm3)'] = arq['B(mg/dm3)'].astype(float)
arq['Mn(mg/dm3)'] = arq['Mn(mg/dm3)'].astype(float)
arq['Carbono'] = arq['Carbono'].astype(float)
arq['Ferro'] = arq['Ferro'].astype(float)
arq['K na CTC'] = arq['K na CTC'].astype(float)
arq['Ca na CTC'] = arq['Ca na CTC'].astype(float)
arq['Mg na CTC'] = arq['Mg na CTC'].astype(float)
arq['CTC pH7'] = arq['CTC pH7'].astype(float)
arq['K %'] = arq['K %'].astype(float)
arq['Mg %'] = arq['Mg %'].astype(float)
arq['Ca %'] = arq['Ca %'].astype(float)
arq['Sodio(mg/dm3)'] = arq['Sodio(mg/dm3)'].astype(float)
arq['Soma de Bases'] = arq['Soma de Bases'].astype(float)
arq['P Resina'] = arq['P Resina'].astype(float)

# %%
arq.to_csv('/content/drive/MyDrive/Faculdade /Projeto CAP/Dados/Embrapa extraido /execlteste.csv')

# %%
teste = pd.read_csv('/content/drive/MyDrive/Faculdade /Projeto CAP/Dados/Embrapa extraido /execlteste.csv')

# %%
teste.dtypes
# Out:
# Unnamed: 0                int64
# OS  Amostra              object
# Talhão                  float64
# Ponto de coleta          object
# ARGILA!                 float64
# H2O(pH)                 float64
# SMP                     float64
# P(mg/dm3)               float64
# K(mg/dm3)               float64
# K(cmolc/dm3)            float64
# M.O.(%)                 float64
# Al(cmolc/dm3)           float64
# Ca(cmolc/dm3)           float64
# Mg(cmolc/dm3)           float64
# Al+H(cmolc/dm3)         float64
# CTC(cmolc/dm3)          float64
# %SAT.CTC(Bases)         float64
# %SAT.CTC(Al)            float64
# Rel.Ca/Mg               float64
# Rel.Ca/K                float64
# Rel.Mg/k                float64
# S(mg/dm3)               float64
# Zn(mg/dm3)              float64
# Cu(mg/dm3)              float64
# B(mg/dm3)               float64
# Mn(mg/dm3)              float64
# Silte(%)                float64
# Carbono                 float64
# Ferro                   float64
# ...
