# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, confusion_matrix, r2_score
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from sklearn.metrics import confusion_matrix
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
sep = ';'
dtype = 'float'

df = pd.read_csv('/content/drive/MyDrive/Faculdade /Projeto CAP/Dados/Indices_voos_blocos_19_e_23_embrapa/Estatisticas/agora vai com prod.csv', sep=sep)

columns_to_drop = [col for col in df.columns if 'Median' in col]

# %%
nova = df.drop(columns=columns_to_drop)

# %%
columns_to_drop = [col for col in nova.columns if col.endswith('.1')]
print(columns_to_drop)
# Out:
# ['Mean_voo1__SAVI.1', 'Mean_voo1__MCARI.1', 'Mean_voo1__GLI.1', 'Mean_voo1__SCCCI.1', 'Mean_voo1__NDVI.1', 'Mean_voo2__NDVI.1', 'Mean_voo2__NDRE.1', 'Mean_voo2__SAVI.1', 'Mean_voo2__MCARI.1', 'Mean_voo2__GLI.1', 'Mean_voo2__SCCCI.1', 'Mean_voo3__NDVI.1', 'Mean_voo3__NDRE.1', 'Mean_voo3__SAVI.1', 'Mean_voo3__MCARI.1', 'Mean_voo3__GLI.1', 'Mean_voo3__SCCCI.1', 'Mean_voo4__NDVI.1', 'Mean_voo4__NDRE.1', 'Mean_voo4__SAVI.1', 'Mean_voo4__MCARI.1', 'Mean_voo4__GLI.1', 'Mean_voo4__SCCCI.1']

# %%
nova = nova.drop(columns=columns_to_drop)

# %%
nova = nova.drop(columns='Mean')

# %%
nova
# Out:
#     Unnamed: 0  BlockID  Mean_voo1_GLI  Mean_voo1__SAVI  Mean_voo1__MCARI  \
# 0          0.0      1.0      -0.096045         0.098206          0.075760
# 1          1.0      2.0      -0.088841         0.110901          0.072620
# 2          2.0      3.0      -0.087609         0.114523          0.072924
# 3          3.0      4.0      -0.086490         0.113219          0.065928
# 4          4.0      5.0      -0.084605         0.105013          0.058731
# 5          5.0      6.0      -0.088875         0.104896          0.063129
# 6          6.0      7.0      -0.093781         0.104939          0.066522
# 7          7.0      8.0      -0.093101         0.092962          0.073427
# 8          8.0      9.0      -0.100515         0.080972          0.065164
# 9          9.0     10.0      -0.101125         0.085764          0.059700
# 10        10.0     11.0      -0.100294         0.084019          0.052445
# 11        11.0     12.0      -0.102980         0.084488          0.052775
# ...

# %%
nova.to_csv('/content/drive/MyDrive/Faculdade /Projeto CAP/Dados/Indices_voos_blocos_19_e_23_embrapa/Estatisticas/agora vai com prodv2.csv', sep=sep, index= False )
